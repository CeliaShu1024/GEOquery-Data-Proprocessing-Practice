# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
GPL = pd.read_csv("GPL201-30390.csv")
GSE1739 = pd.read_csv("GSE1739.csv")

# %%
GPL.info()
GSE1739.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8793 entries, 0 to 8792
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        8793 non-null   int64
#  1   ID                                8793 non-null   object
#  2   GB_ACC                            8746 non-null   object
#  3   SPOT_ID                           0 non-null      float64
#  4   Species Scientific Name           8793 non-null   object
#  5   Annotation Date                   8793 non-null   object
#  6   Sequence Type                     8793 non-null   object
#  7   Sequence Source                   8793 non-null   object
#  8   Target Description                8793 non-null   object
#  9   Representative Public ID          8793 non-null   object
#  10  Gene Title                        8683 non-null   object
#  11  Gene Symbol                       8688 non-null   object
#  12  ENTREZ_GENE_ID                    8676 non-null   object
#  13  RefSeq Transcript ID              8672 non-null   object
#  14  Gene Ontology Biological Process  8328 non-null   object
#  15  Gene Ontology Cellular Component  8428 non-null   object
#  16  Gene Ontology Molecular Function  8280 non-null   object
# dtypes: float64(1), int64(1), object(15)
# memory usage: 1.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8793 entries, 0 to 8792
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        8793 non-null   object
#  1   GSM30361  8793 non-null   float64
#  2   GSM30362  8793 non-null   float64
#  3   GSM30363  8793 non-null   float64
#  4   GSM30364  8793 non-null   float64
#  5   GSM30365  8793 non-null   float64
#  6   GSM30366  8793 non-null   float64
#  7   GSM30367  8793 non-null   float64
#  8   GSM30368  8793 non-null   float64
#  9   GSM30369  8793 non-null   float64
#  10  GSM30370  8793 non-null   float64
#  11  GSM30371  8793 non-null   float64
#  12  GSM30372  8793 non-null   float64
#  13  GSM30373  8793 non-null   float64
#  14  GSM30374  8793 non-null   float64
# dtypes: float64(14), object(1)
# memory usage: 1.0+ MB

# %%
GSE1739.insert(15, 'Gene Symbol', GPL['Gene Symbol'])
for key, values in GSE1739.iteritems():
    print(key, values)
# Out:
# ID 0                  1007_s_at
# 1                    1053_at
# 2                     117_at
# 3                     121_at
# 4                  1255_g_at
#                 ...
# 8788    AFFX-r2-Ec-bioC-5_at
# 8789    AFFX-r2-Ec-bioD-3_at
# 8790    AFFX-r2-Ec-bioD-5_at
# 8791     AFFX-r2-P1-cre-3_at
# 8792     AFFX-r2-P1-cre-5_at
# Name: ID, Length: 8793, dtype: object
# GSM30361 0         321.8
# 1         204.8
# 2         538.6
# 3        1277.8
# 4          51.3
#          ...
# 8788      522.0
# 8789     2351.0
# 8790     1828.3
# 8791    10217.3
# 8792    10460.3
# Name: GSM30361, Length: 8793, dtype: float64
# GSM30362 0         257.1
# 1         293.5
# 2         367.0
# 3         880.2
# 4          44.0
#          ...
# 8788      776.0
# 8789     3234.6
# 8790     2981.5
# 8791    15178.5
# 8792    13351.5
# Name: GSM30362, Length: 8793, dtype: float64
# GSM30363 0         331.0
# 1         217.4
# 2         529.0
# 3        1031.8
# 4          41.5
#          ...
# 8788      992.4
# 8789     4671.0
# 8790     3793.1
# 8791    14755.9
# 8792    14101.6
# Name: GSM30363, Length: 8793, dtype: float64
# GSM30364 0         366.8
# 1         261.8
# 2         362.1
# 3        1036.1
# 4          26.4
#          ...
# 8788      511.1
# 8789     2529.0
# 8790     1823.5
# 8791    10256.1
# 8792     9051.6
# Name: GSM30364, Length: 8793, dtype: float64
# GSM30365 0         205.2
# 1         215.8
# 2         561.1
# 3         790.9
# 4          53.5
#          ...
# 8788     1897.7
# 8789     7235.4
# 8790     5888.8
# 8791    32363.3
# 8792    30772.5
# Name: GSM30365, Length: 8793, dtype: float64
# GSM30366 0          223.9
# 1          265.6
# 2          365.4
# 3         1016.1
# 4           36.5
#           ...
# 8788      7411.9
# 8789     28870.7
# 8790     21497.1
# 8791    113747.3
# 8792     97933.8
# Name: GSM30366, Length: 8793, dtype: float64
# GSM30367 0          262.1
# 1           56.1
# 2          275.6
# 3         1165.7
# 4           22.3
#           ...
# 8788     29043.3
# 8789    106993.0
# 8790     92436.5
# 8791    308413.6
# 8792    277865.2
# Name: GSM30367, Length: 8793, dtype: float64
# GSM30368 0         313.5
# 1         203.5
# 2        1037.3
# 3        1189.1
# 4          73.7
#          ...
# 8788     6118.4
# 8789    15693.7
# 8790    12489.7
# 8791    54084.5
# 8792    50116.5
# Name: GSM30368, Length: 8793, dtype: float64
# GSM30369 0         255.5
# 1         179.6
# 2         565.9
# 3        1039.6
# 4          51.0
#          ...
# 8788      751.9
# 8789     3350.2
# 8790     2316.6
# 8791    13091.9
# 8792    12611.5
# Name: GSM30369, Length: 8793, dtype: float64
# GSM30370 0         235.5
# 1         136.2
# 2         588.7
# 3         992.4
# 4          42.5
#          ...
# 8788     1724.9
# 8789     6380.2
# 8790     4839.7
# 8791    25371.5
# 8792    23734.6
# Name: GSM30370, Length: 8793, dtype: float64
# GSM30371 0         197.0
# 1         189.5
# 2        1153.8
# 3         853.7
# 4          64.1
#          ...
# 8788      601.6
# 8789     2555.6
# 8790     1657.5
# 8791    11938.1
# 8792     9679.9
# Name: GSM30371, Length: 8793, dtype: float64
# GSM30372 0         197.4
# 1         158.6
# 2        1401.4
# 3        1088.2
# 4          33.3
#          ...
# 8788     1845.6
# 8789     7894.7
# 8790     5810.9
# 8791    35379.6
# 8792    30348.9
# Name: GSM30372, Length: 8793, dtype: float64
# GSM30373 0         291.4
# 1          67.3
# 2         256.0
# 3         709.9
# 4          35.1
#          ...
# 8788     1428.1
# 8789     5431.3
# 8790     4857.2
# 8791    19950.7
# 8792    18666.2
# Name: GSM30373, Length: 8793, dtype: float64
# GSM30374 0         132.6
# 1         153.3
# 2         423.1
# 3         747.4
# 4          74.2
#          ...
# 8788      591.0
# 8789     2966.9
# 8790     1507.8
# 8791    12141.4
# 8792    10101.9
# Name: GSM30374, Length: 8793, dtype: float64
# Gene Symbol 0       DDR1 /// MIR4640
# 1                   RFC2
# 2                  HSPA6
# 3                   PAX8
# 4                 GUCA1A
#               ...
# 8788                 NaN
# 8789                 NaN
# 8790                 NaN
# 8791                 NaN
# 8792                 NaN
# Name: Gene Symbol, Length: 8793, dtype: object

# %%
GSE1739 = GSE1739.dropna(axis='index', subset='Gene Symbol')
tmp = GSE1739['Gene Symbol']
tmp
# Out:
# 0       DDR1 /// MIR4640
# 1                   RFC2
# 2                  HSPA6
# 3                   PAX8
# 4                 GUCA1A
#               ...
# 8760               GAPDH
# 8761               STAT1
# 8762               STAT1
# 8763               STAT1
# 8764               STAT1
# Name: Gene Symbol, Length: 8688, dtype: object

# %%
import re
regex = r"\d{2}(:)\d{2}(:)\d{2}"
def CheckStr(s):
    if re.findall(regex, s):
        return 1
    else:
        return 0
matched_index = []
for key, value in tmp.items():
    if CheckStr(value) == 1:
        matched_index.append(key)
print(matched_index)
matched_index = np.array(matched_index)
print("Date rows: ", matched_index)
GSE1739.loc[matched_index,:]
# Out:
# [33, 293, 739, 1245, 5861, 6250, 8008, 8686]
# Date rows:  [  33  293  739 1245 5861 6250 8008 8686]
#                ID  GSM30361  GSM30362  GSM30363  GSM30364  GSM30365  GSM30366  \
# 33    200015_s_at    3062.1    2234.8    2483.2    2354.1    2199.2    1934.6
# 293     200902_at    1719.2    2213.0    1989.9    1812.1    1338.8     937.1
# 739   201737_s_at     157.7     193.3     248.1     177.3     364.5     281.6
# 1245  202653_s_at    1124.3    1168.5    1046.9    1132.6     603.1     802.6
# 5861  210657_s_at      28.4      57.0      97.3      73.6     105.3      97.3
# 6250  213151_s_at    4516.5    3738.6    3138.5    3384.3    3474.0    3009.7
# 8008    220781_at     162.7     101.6      84.0     124.3      99.1       7.0
# 8686     41220_at    8648.0    8047.0    7203.3    5122.7    8964.1    5342.2
#
#       GSM30367  GSM30368  GSM30369  GSM30370  GSM30371  GSM30372  GSM30373  \
# 33      4561.7    1105.9    1975.9    1795.9    2521.0    1611.0    2304.6
# 293      932.1     609.7     998.7    1036.8    1136.7    1044.9    1310.8
# 739      155.0     251.8     186.9      97.6     108.6     157.2     166.3
# 1245    1560.6     769.7     513.0     546.6    1392.7    1258.4     871.7
# 5861      37.2      89.3     151.9     164.1     151.7      84.4      97.8
# 6250    4218.3    2099.8    2390.2    1885.2    2983.6    2266.7    4466.5
# 8008     197.1      27.8      38.4      63.9      63.8      79.3      17.8
# 8686   19947.9   12602.3    6972.6    8207.6    4586.0    2297.1    8263.9
#
#       GSM30374          Gene Symbol
# 33      1643.9  2022-09-02 00:00:00
# 293      815.3  2022-09-15 00:00:00
# 739       72.7  2022-03-06 00:00:00
# 1245    1236.2  2022-03-07 00:00:00
# 5861      91.4  2022-09-04 00:00:00
# 6250    2865.5  2022-09-07 00:00:00
# 8008      50.2  2022-12-01 00:00:00
# 8686    2889.0  2022-09-09 00:00:00

# %%
GSE1739 = GSE1739.drop(axis='index', index=matched_index)
GSE1739
# Out:
#                                ID  GSM30361  GSM30362  GSM30363  GSM30364  \
# 0                       1007_s_at     321.8     257.1     331.0     366.8
# 1                         1053_at     204.8     293.5     217.4     261.8
# 2                          117_at     538.6     367.0     529.0     362.1
# 3                          121_at    1277.8     880.2    1031.8    1036.1
# 4                       1255_g_at      51.3      44.0      41.5      26.4
# ...                           ...       ...       ...       ...       ...
# 8760    AFFX-HUMGAPDH/M33197_5_at    5207.9    6875.5    9697.3    7679.3
# 8761    AFFX-HUMGAPDH/M33197_M_at    4346.0    6221.2    7472.1    6790.3
# 8762   AFFX-HUMISGF3A/M97935_3_at    1829.0    4101.3    2483.8    1581.5
# 8763   AFFX-HUMISGF3A/M97935_5_at     282.0    1235.2     424.1     301.1
# 8764  AFFX-HUMISGF3A/M97935_MA_at     584.8    2600.2    1199.8     741.4
#
#       GSM30365  GSM30366  GSM30367  GSM30368  GSM30369  GSM30370  GSM30371  \
# 0        205.2     223.9     262.1     313.5     255.5     235.5     197.0
# 1        215.8     265.6      56.1     203.5     179.6     136.2     189.5
# 2        561.1     365.4     275.6    1037.3     565.9     588.7    1153.8
# 3        790.9    1016.1    1165.7    1189.1    1039.6     992.4     853.7
# 4         53.5      36.5      22.3      73.7      51.0      42.5      64.1
# ...        ...       ...       ...       ...       ...       ...       ...
# 8760   11934.9   12643.1     873.6   10359.7   11541.9   11177.9    7324.6
# 8761   11943.5   13723.2     109.9   12465.1   10841.8   14101.9    8580.5
# 8762    1454.2    1724.4    3222.0    1446.2     738.0    2401.5     824.7
# 8763     131.8      58.3       7.9     107.1      63.5      92.8      30.6
# 8764     287.5     542.1      21.7     581.7     182.3     530.3      27.5
#
#       GSM30372  GSM30373  GSM30374       Gene Symbol
# 0        197.4     291.4     132.6  DDR1 /// MIR4640
# 1        158.6      67.3     153.3              RFC2
# 2       1401.4     256.0     423.1             HSPA6
# 3       1088.2     709.9     747.4              PAX8
# 4         33.3      35.1      74.2            GUCA1A
# ...        ...       ...       ...               ...
# 8760    9933.5    7822.6   11730.0             GAPDH
# 8761   12620.4    8194.4   10377.9             STAT1
# 8762    1554.4    1777.6    1095.8             STAT1
# 8763      98.8     100.4      53.2             STAT1
# 8764     165.0     307.7     207.4             STAT1
#
# [8680 rows x 16 columns]

# %%
tmp = GSE1739['Gene Symbol'].values.tolist()
sym = []
for s in tmp:
    str = '' ''
    s = s.split('///')
    s = str.join(s)
    sym.append(s)
sym
# Out:
# ['DDR1  MIR4640',
#  'RFC2',
#  'HSPA6',
#  'PAX8',
#  'GUCA1A',
#  'MIR5193  UBA7',
#  'THRA',
#  'PTPN21',
#  'CYP2E1',
#  'EPHB3',
#  'ESRRA',
#  'CYP2A6',
#  'GAS6',
#  'MMP14',
#  'TRADD',
#  'CHURC1-FNTB  FNTB',
#  'PLD1',
#  'BAD',
#  'PRPF8',
#  'CAPNS1',
#  'RPL35',
#  'MIR6805  RPL28',
#  'EIF4G2',
#  'EIF3D',
#  'PARK7',
#  'SRP14',
#  'GDI2',
#  'GDI2',
#  'RPL11',
#  'ARF3',
#  'RPL21  RPL21P28  SNORA27  SNORD102',
#  'RPL24',
#  'HNRNPC',
#  'HNRNPA1  HNRNPA1P10',
#  'RPS27A',
#  'LOC100508408  RPS13  SNORD14B',
#  'FAU',
#  'TARDBP',
#  'CFL1',
#  'RPL18',
#  'EIF3F',
#  'RPS5',
#  'RPL27',
#  'RPL34',
#  'NARS',
#  'STARD7',
#  'RPL19',
#  'SLC25A3',
#  'RPS11  SNORD35B',
#  'RPL9',
#  'DDX5  MIR3064  MIR5047',
#  'RPL6',
#  'CTDNEP1',
#  'RPL10A',
#  'CBX3',
#  'C18orf32  RPL17  RPL17-C18orf32  SNORD58A  SNORD58B  SNORD58C',
#  'PSMB2',
#  'KHDRBS1',
#  'ATP6V1G2-DDX39B  DDX39B  SNORD84',
#  'RTCB',
#  'ERH',
#  'GATC  SRSF9',
#  'ABCF1',
#  'DAD1',
#  'YY1',
#  'JTB',
#  'KAT7',
#  'ZNF146',
#  'SART1',
#  'ILF2',
#  'SPAG7',
#  'ZPR1',
#  'TAF10',
#  'C1D',
#  'NONO',
#  'LOC101929240  SNRNP200',
#  'RHOA',
#  'RNPS1',
#  'RPS24',
#  'RPL30',
#  'NPM1',
#  'HSP90AB1',
#  'ARF1  MIR3620',
#  'IK',
#  'SNX3',
#  'CANX',
#  'SART3',
#  'CNPPD1',
#  'SMNDC1',
#  'HNRNPM',
#  'HNRNPD',
#  'RPL14',
#  'GUK1',
#  'KXD1',
#  'OAZ1',
#  'ATP6V0B',
#  'KARS',
#  'H3F3A  H3F3AP4  H3F3B',
#  'RPS6',
#  'RPS7',
#  'USP22',
#  'C11orf58',
#  'TCEB2',
#  'COX4I1',
#  'TMED2',
#  'NBEAL1  RPL12',
#  'RPL4  SNORD16  SNORD18A  SNORD18B  SNORD18C',
#  'FNTA',
#  'RPS25',
#  'RPL37',
#  'HINT1',
#  'EEF2',
#  'RPS10',
#  'ATP6V0E1',
#  'HNRNPK',
#  'ANAPC5',
#  'RPS3A  SNORD73A',
#  'HNRNPU',
#  'EIF3A',
#  'HSP90B1  MIR3652',
#  'MSN',
#  'ACTN4',
#  'APP',
#  'PRKAR1A',
#  'DSP',
#  'RAD21',
#  'WDR1',
#  'NCL',
#  'AP2B1',
#  'AP2M1',
#  'CLTC',
#  'LASP1',
#  'SF3B2',
#  'TMEM59',
#  'CSRP1',
#  'CALM1  CALM2  CALM3',
#  'MATR3  SNHG4',
#  'PTGES3',
#  'WARS',
#  'SET  SETSIP',
#  'NDRG1',
#  'UBB',
#  'PFN1',
#  'PTPRF',
#  'YWHAZ',
#  'SOD1',
#  'HDLBP',
#  'MARCKSL1',
#  'GABARAP',
#  'NUCB1',
#  'LDHA',
#  'GNB2L1  SNORD95  SNORD96A',
#  'SSR2',
#  'CALM1  CALM2  CALM3',
#  'P4HB',
#  'SLC25A5',
#  'PHB',
#  'S100A11',
#  'CTSA',
#  'TOMM20',
#  'CD63',
#  'SPARC',
#  'DNAJB1',
#  'UBE2D3',
#  'XBP1',
#  'LAPTM4A',
#  'RPL32',
#  'CD81',
#  'PTTG1IP',
#  'HMGB1',
#  'GLO1',
#  'UBE2L3',
#  'SRSF11',
#  'SF3B3',
#  'HSPA9',
#  'DDX24',
#  'PPP2R1A',
#  'GSN',
#  'HK1',
#  'KDELR2',
#  'NPC2',
#  'DYNLL1',
#  'LITAF',
#  'EEF1B2  SNORA41',
#  'PRKCSH',
#  'GOT2',
#  'FKBP1A  LOC101929368',
#  'ACADVL',
#  'MAPRE1',
#  'RPL13A  RPL13AP5  SNORD32A  SNORD33  SNORD34  SNORD35A',
#  'RPL7',
#  'SKP1',
#  'ACTR1A',
#  'CAPRIN1',
#  'PPP1CC',
#  'ACTR2',
#  'PTP4A1',
#  'NACA',
#  'GPX1',
#  'PGK1',
#  'SUMO3',
#  'RPS27',
#  'TPP1',
#  'GNB1',
#  'NUMA1',
#  'FTH1',
#  'RAN',
#  'CAPN1',
#  'CALU',
#  'ARL6IP5',
#  'DPYSL2',
#  'RPLP1',
#  'CTNNA1',
#  'CTSD',
#  'MAT2A',
#  'LAMC1',
#  'PTMA',
#  'ATF4',
#  'RPS15A',
#  'ANXA5',
#  'STMN1',
#  'LRP1',
#  'PSMB7',
#  'PEA15',
#  'ECH1',
#  'ODC1',
#  'XRCC6',
#  'ACO2',
#  'SPARCL1',
#  'MCL1',
#  'HSPA1A  HSPA1B  HSPA1L',
#  'SARS',
#  'TMBIM6',
#  'LMAN2',
#  'HSPD1',
#  'ZYX',
#  'RPL12',
#  'CIRBP',
#  'CCT7',
#  'PSME1',
#  'PAFAH1B1',
#  'RPS10',
#  'ATP5O',
#  'RPS15',
#  'PSMD8',
#  'LAMP2',
#  'RPL29',
#  'GSTP1',
#  'HYOU1',
#  'SNRPD2',
#  'PLOD1',
#  'ZNF207',
#  'PSMD2',
#  'SCD',
#  'RPS21',
#  'BCAP31',
#  'CTSB',
#  'KARS',
#  'EPRS',
#  'PRDX6',
#  'PPP1CA',
#  'SARAF',
#  'AHCYL1',
#  'GNB2',
#  'H2AFZ',
#  'NCOR1',
#  'RPS8  SNORD38B  SNORD55',
#  'DHCR24',
#  'RAB11A',
#  'PSAP',
#  'RNF114',
#  'RPL18A  SNORA68',
#  'STRAP',
#  'S100A10',
#  'CCT8',
#  'MIR1292  NOP56  SNORD110  SNORD57  SNORD86',
#  'PSMB1',
#  'CCT4',
#  'EPAS1',
#  'DNAJA1',
#  'PSMD4',
#  'CKB',
#  'RHOC',
#  'PGAM1',
#  'STAT1',
#  'RPL23  SNORA21',
#  'SSR1',
#  'TRA2B',
#  'FKBP4',
#  'HDGF',
#  'MGEA5',
#  'M6PR  PHC1',
#  'AHCY',
#  'HLA-E',
#  'RPLP2  SNORA52',
#  'CCT3  LOC101927137',
#  'TACC1',
#  'EIF4A2  MIR1248  SNORA4  SNORA63  SNORA81  SNORD2',
#  'PPM1G',
#  'SRPR',
#  'PHC2',
#  'BTG1',
#  'KDELR1',
#  'LGALS3BP',
#  'SLC3A2',
#  'COX6A1',
#  'RPS23',
#  'TMED10',
#  'VCL',
#  'DCTN2',
#  'RPS4X',
#  'DEK',
#  'RPL8',
#  'RPL5  SNORD21',
#  'RERE',
#  'HSBP1',
#  'HMGN1  LOC101927733',
#  'SEC31A',
#  'GLUD1',
#  'MLF2',
#  'ARPC1A',
#  'CCND2',
#  'IMMT',
#  'SSRP1',
#  'SDCBP',
#  'FUS',
#  'SEPHS2',
#  'RPL31',
#  'UBA1',
#  'ABLIM1',
#  'ALDOA',
#  'PPIB',
#  'LOC101928061  SERP1',
#  'TSPAN3',
#  'ACTA2',
#  'PPT1',
#  'TAX1BP1',
#  'MDH1',
#  'PDHA1',
#  'ANXA6',
#  'CD59',
#  'SERPING1',
#  'PSME3',
#  'HIF1A',
#  'TRIM28',
#  'IPO7',
#  'ACTR3',
#  'RBM14-RBM4  RBM4',
#  'CKAP4',
#  'AARS',
#  'TMEM189  TMEM189-UBE2V1  UBE2V1  UBE2V2',
#  'SSR4',
#  'CD9',
#  'HADHB',
#  'TXNIP',
#  'RPN1',
#  'ANXA1',
#  'PAICS',
#  'JUP',
#  'EIF1AX',
#  'YWHAH',
#  'DSTN',
#  'TAF7',
#  'CD99',
#  'LDHB',
#  'HNRNPH1',
#  'BLCAP',
#  'ADD3',
#  'PFKP',
#  'RAD23A',
#  'GNAI2',
#  'DUSP1',
#  'TGM2',
#  'RPS18',
#  'PLD3',
#  'ANP32A',
#  'PSMF1',
#  'HNRNPA0',
#  'GOLGB1',
#  'MYL9',
#  'CTTN',
#  'RCN1',
#  'LOC100996696  PABPC4',
#  'CYC1',
#  'PSMC2',
#  'MMP2',
#  'SMARCC1',
#  'ANXA2  NHP2L1',
#  'TM9SF2',
#  'SYNGR2',
#  'PIP4K2B',
#  'DCTN1  SLC4A5',
#  'PXN',
#  'KPNA2',
#  'ATP6V1B2',
#  'RBBP7',
#  'RPS29',
#  'DAP',
#  'ARF4',
#  'COPB2',
#  'USP9X',
#  'PFKL',
#  'LGALS1',
#  'GPX4',
#  'THBS1',
#  'CSE1L',
#  'TUFM',
#  'POLD2',
#  'CPE',
#  'PGD',
#  'COX8A',
#  'PGRMC1',
#  'ITGB5',
#  'MGAT1',
#  'ACLY',
#  'SRSF7',
#  'CDH1',
#  'HNRNPH2  RPL36A-HNRNPH2',
#  'ECHS1',
#  'PLP2',
#  'HLA-DPB1',
#  'SSB',
#  'RAB5C',
#  'GPNMB',
#  'EIF2S1',
#  'HAX1',
#  'NFE2L2',
#  'TIMP3',
#  'MBNL1',
#  'NMT1',
#  'YBX3',
#  'IGFBP7',
#  'PUM1',
#  'BHLHE40',
#  'TERF2IP',
#  'ARCN1',
#  'UBA2',
#  'FBXO7',
#  'GNAI3',
#  'CHD4',
#  'HTRA1',
#  'LRPAP1',
#  'ITPR3',
#  'PITPNA',
#  'IDH1',
#  'SEPW1',
#  'SLC7A5',
#  'AMD1',
#  'PSMD1',
#  'CREG1',
#  'CSTB',
#  'PCNA',
#  'TNFAIP1',
#  'HDAC1',
#  'DDX3X',
#  'LGMN',
#  'PLS3',
#  'ERP29',
#  'SNRNP70',
#  'RAD23B',
#  'SRRM1',
#  'NDUFB8',
#  'ARIH2',
#  'ENO1',
#  'PSMD13',
#  'ILK',
#  'BTG2',
#  'CAPZA2',
#  'DDX1',
#  'ATP1B1',
#  'RAF1',
#  'SREBF2',
#  'SLC2A1',
#  'PKM',
#  'PSMC4',
#  'CDIPT',
#  'COX7A2L',
#  'RPS3A  SNORD73A',
#  'RPS16',
#  'SYPL1',
#  'BGN',
#  'TARS',
#  'COPE',
#  'TXNRD1',
#  'PSMC3',
#  'NME1-NME2  NME2',
#  'RALY',
#  'AKR1B1',
#  'SRP9',
#  'PSMA5',
#  'FDPS',
#  'RAB5B',
#  'HNRNPAB',
#  'DAB2  LOC101926921',
#  'ADRM1',
#  'OGDH',
#  'APEH',
#  'MKRN1',
#  'SDC1',
#  'ARHGDIB',
#  'CYR61',
#  'SEC11A',
#  'TOP2A',
#  'LOC101060363  PPIA',
#  'PRNP',
#  'ANXA4',
#  'NDUFA5',
#  'SH3BGRL',
#  'ENO2',
#  'STK25',
#  'IFITM2',
#  'PSMA2',
#  'MYL12A  MYL12B',
#  'SMARCC2',
#  'ATP5B',
#  'EBNA1BP2  MIR6733',
#  'EMP1',
#  'CCT6A',
#  'ETS2',
#  'RARS',
#  'STAT6',
#  'VAMP3',
#  'SCP2',
#  'ENC1',
#  'SNRPC',
#  'UBE2D2',
#  'GPX3',
#  'SLC9A3R1',
#  'FLOT2',
#  'YME1L1',
#  'BAZ2A',
#  'SF3A1',
#  'COPB1',
#  'CST3',
#  'IVNS1ABP',
#  'OAZ2',
#  'ZFP36L2',
#  'CUL3',
#  'PLEC',
#  'PPP2CB',
#  'HNRNPF',
#  'TPD52L2',
#  'CRTAP',
#  'NBR1',
#  'DHX15',
#  'UCHL1',
#  'PSMD3',
#  'ITGA5',
#  'CSNK2B',
#  'TRAP1',
#  'IGF2R',
#  'RBM5',
#  'SGTA',
#  'PHGDH',
#  'TRAM1',
#  'PSMB3',
#  'MGST3',
#  'COPS6',
#  'RPL36A  RPL36A-HNRNPH2',
#  'PPP1CB',
#  'HSD17B4',
#  'NAP1L4',
#  'GSS',
#  'SOX4',
#  'BAP1',
#  'IFI30  PIK3R2',
#  'CUL4A',
#  'ALDH2',
#  'VIM',
#  'SEPP1',
#  'CLDN4',
#  'RPL37A',
#  'DPYSL3',
#  'CAT',
#  'PTDSS1',
#  'TTC1',
#  'EIF4E',
#  'COL6A3',
#  'GBF1',
#  'COX6B1',
#  'ATP6AP2',
#  'CNN3',
#  'TIA1',
#  'NPEPPS',
#  'BUB3',
#  'RUVBL2',
#  'MAPKAPK2',
#  'TALDO1',
#  'NQO1',
#  'GSTO1',
#  'SQSTM1',
#  'VBP1',
#  'JUNB',
#  'ITGA3',
#  'RRM1',
#  'DKC1  MIR664B  SNORA56',
#  'SUPT5H',
#  'PYGB',
#  'QSOX1',
#  'SUPT4H1',
#  'RCN2',
#  'CTSC',
#  'PPIF',
#  'AHSA1',
#  'RPL41',
#  'PRCP',
#  'MYH11',
#  'USP7',
#  'PPP1R11',
#  'NFKBIA',
#  'G3BP1',
#  'LAMB1',
#  'TGFBI',
#  'PFDN1',
#  'IGFBP4',
#  'AAMP',
#  'TSN',
#  'SRM',
#  'NCBP2',
#  'CBX1',
#  'GRSF1',
#  'SNRPN  SNURF',
#  'APOD',
#  'ARF5',
#  'ATP6V1F  LOC101927180',
#  'RPA1',
#  'EIF4A1  LOC101928634  SENP3-EIF4A1  SNORA48  SNORA67  SNORD10',
#  'ZFP36',
#  'PSMA3',
#  'CTNNB1',
#  'UBL3',
#  'DUSP3',
#  'FHL1',
#  'ZNHIT1',
#  'TRIP12',
#  'KDM5B',
#  'LAMP1',
#  'MCM3',
#  'VAMP2',
#  'RAE1',
#  'CLIC4',
#  'SORD',
#  'FSCN1',
#  'ID2',
#  'GOLGA4',
#  'UQCRQ',
#  'ETF1',
#  'SNW1',
#  'GLB1  TMPPE',
#  'NME1',
#  'PODXL',
#  'FAT1',
#  'DDX39A',
#  'SFPQ',
#  'IRAK1',
#  'TXNL1',
#  'SMC1A',
#  'ANXA2',
#  'NISCH',
#  'EIF3H',
#  'PPP4R1',
#  'KRT18',
#  'COX7A2',
#  'INPPL1',
#  'OAT',
#  'PHB2',
#  'PPP1R12A',
#  'CNN2',
#  'PWP1',
#  'ICMT',
#  'ALDH9A1',
#  'RUVBL1',
#  'CALD1',
#  'PRDX3',
#  'MBTPS1',
#  'SND1',
#  'DARS',
#  'INSIG1',
#  'RRAGA',
#  'ACP1',
#  'IER3',
#  'EIF2B1',
#  'CYB5B',
#  'FXR1',
#  'BST2',
#  'IFNGR2',
#  'TNC',
#  'SCARB2',
#  'JAK1',
#  'UBE2L6',
#  'KRT19',
#  'PACSIN2',
#  'COPS5',
#  'CNIH1',
#  'HSPG2',
#  'ITGA6',
#  'ARL1',
#  'ACSL3',
#  'SMC4',
#  'RPS17',
#  'TIMP1',
#  'GJA1',
#  'MARCKS',
#  'USP14',
#  'GYS1',
#  'AKAP1',
#  'DLG5',
#  'PMPCB',
#  'API5',
#  'TPD52',
#  'SIGMAR1',
#  'EGR1',
#  'PNP',
#  'SRSF4',
#  'DNMT1',
#  'GATC  SRSF9',
#  'PSMC6',
#  'CCND3',
#  'PGRMC2',
#  'PPP1R10',
#  'ENTPD6',
#  'PSMD7',
#  'PEX19',
#  'NIPSNAP1',
#  'MYBL2',
#  'RANBP2',
#  'TUBG1',
#  'SNX1',
#  'MRPL49',
#  'EPB41L2',
#  'LAPTM5',
#  'GALNT1',
#  'CDC123',
#  'ELAVL1',
#  'TPR',
#  'CLCN3',
#  'EIF1B',
#  'SGK1',
#  'NDUFS3',
#  'CD14',
#  'LUM',
#  'TWF1',
#  'TP53',
#  'SAFB',
#  'ECE1',
#  'ADD3',
#  'COX6C',
#  'RPA2',
#  'NDUFS5  RPL10',
#  'TSG101',
#  'TBCD',
#  'WSB2',
#  'MTHFD2',
#  'MIR7703  PSME2',
#  'HEXA',
#  'ELAC2',
#  'SNRPA',
#  'SCAMP3',
#  'AZIN1',
#  'RNF13',
#  'AIP',
#  'RELA',
#  'C11orf58',
#  'RNASE1',
#  'ADAR',
#  'DDX42',
#  'DHCR7',
#  'AEBP1',
#  'LBR',
#  'VARS',
#  'MYOF',
#  'OSBP',
#  'SLC29A1',
#  'POLR2B',
#  'PRKAG1',
#  'ATXN2L',
#  'VPS26A',
#  'ENG',
#  'SH3BP5',
#  'C4orf46  TOMM7',
#  'GBAS',
#  'SCARB1',
#  'KRT5',
#  'RNF14',
#  'SMARCD2',
#  'FAM127A',
#  'NET1',
#  'USO1',
#  'HDAC2',
#  'PRKAB1',
#  'EPCAM',
#  'NEDD8',
#  'HSPB1',
#  'EFEMP1',
#  'RYBP',
#  'LIPA',
#  'BNIP3',
#  'CAPG',
#  'SH3GL1',
#  'CDC25B',
#  'ZFR',
#  'SRGN',
#  'PLAT',
#  'LRRFIP1',
#  'GDI1',
#  'TOMM34',
#  'UBXN1',
#  'ABCE1',
#  'PON2',
#  'PPP2R5C',
#  'ARIH1',
#  'B4GALT1',
#  'CEACAM5',
#  'CYB5R3',
#  'DCAF11',
#  'IL13RA1',
#  'B2M',
#  'IMPDH2',
#  'SSR1',
#  'ARAF',
#  'CKS1B',
#  'UBE2A',
#  'AKR1A1',
#  'YY1',
#  'UQCRC1',
#  'DVL3',
#  'RPS4Y1',
#  'FARP1',
#  'GSPT1',
#  'COASY',
#  'SEC63',
#  'SLC20A1',
#  'GNG10',
#  'PRDX4',
#  'AFF1',
#  'CD55',
#  'PKP4',
#  'MCM6',
#  'ETFA',
#  'CHMP1A',
#  'EIF4G3',
#  'CDK2AP1',
#  'PLK2',
#  'CPD',
#  'HEXB',
#  'FURIN',
#  'CCT2',
#  'GNL2',
#  'ALCAM',
#  'CIB1',
#  'ARPC1B',
#  'CCNC',
#  'GNPAT',
#  'PPP1R12B',
#  'ACSL1',
#  'NDUFS2',
#  'RBM6',
#  'PGM1',
#  'NASP',
#  'ATP6V1A',
#  'CLIP1',
#  'MYO10',
#  'RSU1',
#  'MED13',
#  'CREBL2',
#  'KIF5B',
#  'MORF4L2',
#  'EXT1',
#  'ST6GAL1',
#  'DYNLT1',
#  'NDUFA6',
#  'ACAA2',
#  'ST14',
#  'PTPN12',
#  'NID1',
#  'TWF2',
#  'TJP1',
#  'EXT2',
#  'MEST',
#  'EPHX1',
#  'LTF',
#  'LANCL1',
#  'ALDOC',
#  'EFNA1',
#  'ASNA1',
#  'ACAA1',
#  'SDHD',
#  'RPL38',
#  'BCKDK',
#  'MAN2A2',
#  'SFRP1',
#  'UBE4A',
#  'MYO18A  TIAF1',
#  'FIBP',
#  'HARS  LOC101928623',
#  'SMS',
#  'ARHGAP35',
#  'ZMYM4',
#  'RAI14',
#  'ALDH3A2',
#  'SEL1L',
#  'PPFIA1',
#  'LDLR',
#  'IDH3A',
#  'SDC4',
#  'OPTN',
#  'PLTP',
#  'BIRC2',
#  'NDUFAB1',
#  'COPS3',
#  'IER2',
#  'SEC14L1',
#  'TJP2',
#  'MX1',
#  'CTSL',
#  'SLC39A6',
#  'UQCR11',
#  'ARL2BP',
#  'BIRC5',
#  'TSPO',
#  'NUP153',
#  'RALB',
#  'BRD4',
#  'LOC101930112  SPG7',
#  'IGBP1',
#  'GOLGA3',
#  'MCM2',
#  'PEPD',
#  'ARFIP2',
#  'COX7B',
#  'SLC4A2',
#  'VWF',
#  'SNX2',
#  'DPF2',
#  'ARHGAP1',
#  'CPNE3',
#  'CHMP2A',
#  'PLIN3',
#  'ABL1',
#  'TRAK2',
#  'PRPF4B',
#  'RIOK3',
#  'WWTR1',
#  'ACTR1B',
#  'ZMYND11',
#  'AIMP2',
#  'AKR7A2',
#  'CLK3',
#  'COPS8',
#  'ADSL',
#  'LY6E',
#  'IFRD1',
#  'PYCR1',
#  'NEDD9',
#  'UBAC1',
#  'USF2',
#  'TUBB3',
#  'NUP214',
#  'CELF2',
#  'FARSA',
#  'CREBBP',
#  'PKN1',
#  'CNOT8',
#  'PPP1R2',
#  'MMS19',
#  'AK6  TAF9',
#  'AASDHPPT',
#  'VEZF1',
#  'PCM1',
#  'ERCC3',
#  'PRKCZ',
#  'BLMH',
#  'MVP',
#  'KAT2A',
#  'KIF22',
#  'PLOD3',
#  'PPP2R5A',
#  'GAS7',
#  'LIMK2',
#  'DKK3',
#  'MTMR3',
#  'SRPK1',
#  'BLVRB',
#  'LAMA4',
#  'AMFR',
#  'VASP',
#  'ARL4C',
#  'LSM3',
#  'ARFGAP3',
#  'PES1',
#  'CUL4B',
#  'NFYC',
#  'C21orf33',
#  'FADS2',
#  'SLC6A8',
#  'EP300',
#  'DES',
#  'STT3A',
#  'CRK',
#  'BRD8',
#  ...]

# %%
S = {'Gene Symbol':sym}
GS = pd.DataFrame(S)
GS
# Out:
#         Gene Symbol
# 0     DDR1  MIR4640
# 1              RFC2
# 2             HSPA6
# 3              PAX8
# 4            GUCA1A
# ...             ...
# 8675          GAPDH
# 8676          STAT1
# 8677          STAT1
# 8678          STAT1
# 8679          STAT1
#
# [8680 rows x 1 columns]

# %%
GSE1739 = GSE1739.drop(columns='Gene Symbol')
GSE1739 = pd.concat([GSE1739, GS], axis=1, join='inner')
GSE1739
# Out:
#              ID  GSM30361  GSM30362  GSM30363  GSM30364  GSM30365  GSM30366  \
# 0     1007_s_at     321.8     257.1     331.0     366.8     205.2     223.9
# 1       1053_at     204.8     293.5     217.4     261.8     215.8     265.6
# 2        117_at     538.6     367.0     529.0     362.1     561.1     365.4
# 3        121_at    1277.8     880.2    1031.8    1036.1     790.9    1016.1
# 4     1255_g_at      51.3      44.0      41.5      26.4      53.5      36.5
# ...         ...       ...       ...       ...       ...       ...       ...
# 8675   40489_at     274.3     236.4     160.4      38.0     100.5     130.6
# 8676   40524_at      11.3      14.4      10.4      20.4      68.1      80.4
# 8677   40560_at     121.2      34.7      24.8      35.6     104.0     186.3
# 8678   40562_at      98.8      79.8      98.2     141.0     169.8     167.0
# 8679   40569_at     571.8     366.9     457.9     573.0     485.7     339.0
#
#       GSM30367  GSM30368  GSM30369  GSM30370  GSM30371  GSM30372  GSM30373  \
# 0        262.1     313.5     255.5     235.5     197.0     197.4     291.4
# 1         56.1     203.5     179.6     136.2     189.5     158.6      67.3
# 2        275.6    1037.3     565.9     588.7    1153.8    1401.4     256.0
# 3       1165.7    1189.1    1039.6     992.4     853.7    1088.2     709.9
# 4         22.3      73.7      51.0      42.5      64.1      33.3      35.1
# ...        ...       ...       ...       ...       ...       ...       ...
# 8675     175.7     222.6     105.0      41.8     144.3     206.4     228.2
# 8676      59.6      84.6      55.6      29.6      28.2      96.9       9.3
# 8677     217.6     214.8     118.9      81.8      71.2     211.4     119.3
# 8678     130.8     127.9     160.3     200.3      81.9     185.3     116.2
# 8679     736.0     364.4     501.5     523.9     426.1     520.8     407.5
#
#       GSM30374    Gene Symbol
# 0        132.6  DDR1  MIR4640
# 1        153.3           RFC2
# 2        423.1          HSPA6
# 3        747.4           PAX8
# 4         74.2         GUCA1A
# ...        ...            ...
# 8675     103.8          GAPDH
# 8676      22.5          STAT1
# 8677      27.9          STAT1
# 8678     104.9          STAT1
# 8679     357.7          STAT1
#
# [8605 rows x 16 columns]

# %%
print(GSE1739.isna().sum())
GSE1739.info()
# Out:
# ID             0
# GSM30361       0
# GSM30362       0
# GSM30363       0
# GSM30364       0
# GSM30365       0
# GSM30366       0
# GSM30367       0
# GSM30368       0
# GSM30369       0
# GSM30370       0
# GSM30371       0
# GSM30372       0
# GSM30373       0
# GSM30374       0
# Gene Symbol    0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8605 entries, 0 to 8679
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           8605 non-null   object
#  1   GSM30361     8605 non-null   float64
#  2   GSM30362     8605 non-null   float64
#  3   GSM30363     8605 non-null   float64
#  4   GSM30364     8605 non-null   float64
#  5   GSM30365     8605 non-null   float64
#  6   GSM30366     8605 non-null   float64
#  7   GSM30367     8605 non-null   float64
#  8   GSM30368     8605 non-null   float64
#  9   GSM30369     8605 non-null   float64
#  10  GSM30370     8605 non-null   float64
#  11  GSM30371     8605 non-null   float64
#  12  GSM30372     8605 non-null   float64
#  13  GSM30373     8605 non-null   float64
#  14  GSM30374     8605 non-null   float64
#  15  Gene Symbol  8605 non-null   object
# dtypes: float64(14), object(2)
# memory usage: 1.1+ MB

# %%
from sklearn import pipeline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import ColumnTransformer
num_cols = list(GSE1739.select_dtypes(include = 'float64').columns)
norm_pipeline = Pipeline([('scaler', MinMaxScaler())])
preprocess_pipeline = ColumnTransformer([('numcols', norm_pipeline, num_cols)])
tmp = preprocess_pipeline.fit_transform(GSE1739)
tmp
# Out:
# array([[0.01425679, 0.01392034, 0.01661505, ..., 0.00443738, 0.01221855,
#         0.00776469],
#        [0.00906201, 0.01589733, 0.0109041 , ..., 0.00356208, 0.0027993 ,
#         0.00898049],
#        [0.02388268, 0.01988931, 0.026569  , ..., 0.03159854, 0.01073063,
#         0.02482703],
#        ...,
#        [0.00535018, 0.0018412 , 0.00122162, ..., 0.0047532 , 0.00498493,
#         0.0016152 ],
#        [0.00435563, 0.0042907 , 0.00491162, ..., 0.00416441, 0.00485463,
#         0.00613774],
#        [0.02535675, 0.01988388, 0.02299463, ..., 0.01173299, 0.0170984 ,
#         0.0209858 ]])

# %%
num_cols
# Out:
# ['GSM30361',
#  'GSM30362',
#  'GSM30363',
#  'GSM30364',
#  'GSM30365',
#  'GSM30366',
#  'GSM30367',
#  'GSM30368',
#  'GSM30369',
#  'GSM30370',
#  'GSM30371',
#  'GSM30372',
#  'GSM30373',
#  'GSM30374']

# %%
gid = np.array(GSE1739['ID'].tolist())
gs = np.array(GSE1739['Gene Symbol'].tolist())
print(gid, gs)
# Out:
# ['1007_s_at' '1053_at' '117_at' ... '40560_at' '40562_at' '40569_at'] ['DDR1  MIR4640' 'RFC2' 'HSPA6' ... 'STAT1' 'STAT1' 'STAT1']

# %%
cols = ['GSM30361', 'GSM30362', 'GSM30363', 'GSM30364',
        'GSM30365', 'GSM30366', 'GSM30367', 'GSM30368',
        'GSM30369', 'GSM30370', 'GSM30371', 'GSM30372',
        'GSM30373', 'GSM30374', 'ID', 'Gene Symbol']
tmp = np.column_stack((gid, tmp, gs))
tmp
# Out:
# array([['1007_s_at', '0.01425679095663911', '0.01392034499427001', ...,
#         '0.012218546804137576', '0.007764686534553443', 'DDR1  MIR4640'],
#        ['1053_at', '0.009062008826689637', '0.015897327272036018', ...,
#         '0.0027992955526507145', '0.008980488435198348', 'RFC2'],
#        ['117_at', '0.023882677843588218', '0.019889310717525078', ...,
#         '0.010730632951827739', '0.024827027217516947', 'HSPA6'],
#        ...,
#        ['40560_at', '0.005350181595375311', '0.0018412005279194433', ...,
#         '0.004984931719885506', '0.0016151957617263212', 'STAT1'],
#        ['40562_at', '0.004355625016649942', '0.004290703295151505', ...,
#         '0.004854634179146509', '0.006137743894560022', 'STAT1'],
#        ['40569_at', '0.02535675277277046', '0.019883879447531214', ...,
#         '0.017098399862136796', '0.020985798024175075', 'STAT1']],
#       dtype='<U199')

# %%
tmp = pd.DataFrame(tmp, columns=cols)
tmp
# Out:
#        GSM30361               GSM30362               GSM30363  \
# 0     1007_s_at    0.01425679095663911    0.01392034499427001
# 1       1053_at   0.009062008826689637   0.015897327272036018
# 2        117_at   0.023882677843588218   0.019889310717525078
# 3        121_at     0.0567030449415254   0.047762588326028275
# 4     1255_g_at  0.0022466322715849855   0.002346308637348671
# ...         ...                    ...                    ...
# 8600   40489_at   0.012147798211574152   0.012796072105540436
# 8601   40524_at  0.0004706383810039694  0.0007386527191653224
# 8602   40560_at   0.005350181595375311  0.0018412005279194433
# 8603   40562_at   0.004355625016649942   0.004290703295151505
# 8604   40569_at    0.02535675277277046   0.019883879447531214
#
#                    GSM30364               GSM30365               GSM30366  \
# 0      0.016615053590460296   0.024912750947324022   0.004515519184854482
# 1      0.010904100223209798    0.01776955365221473   0.004750725589569261
# 2       0.02656900400168916   0.024593007830304846   0.012412685169570503
# 3       0.05184600534899154    0.07044553141986352     0.0175117825095192
# 4      0.002061171549799916  0.0017551856210839972  0.0011494048834175047
# ...                     ...                    ...                    ...
# 8600   0.008038569044219672     0.0025443388460675   0.002192301206209449
# 8601  0.0004976975205614431  0.0013470029185063234   0.001473368421986917
# 8602  0.0012216211868326331  0.0023810657650364304  0.0022699636983322534
# 8603   0.004911620985742726   0.009551475240317566  0.0037300185502409755
# 8604   0.022994630899475156    0.03894062982591008   0.010739613196410659
#
#                    GSM30367                GSM30368               GSM30369  \
# 0     0.0022565166907388755    0.001762089970640902   0.004849023974520074
# 1      0.002678286058752372  0.00036112303142042413   0.003138335593515558
# 2     0.0036877005174513395   0.0018539009108325352   0.016105353521529787
# 3      0.010269123245661945     0.00790730223413422    0.01846610348731602
# 4     0.0003610831280115547   0.0001312556404221127  0.0011197233039302288
# ...                     ...                     ...                    ...
# 8600  0.0013128456587086776    0.001174499953414449  0.0034353733033081597
# 8601  0.0008051041173590968   0.0003849258677664031  0.0012892369707752215
# 8602  0.0018762162533933723   0.0014594539085277403  0.0033140699453823854
# 8603  0.0016810088480537922   0.0008691435671474614  0.0019626261243888177
# 8604  0.0034206810614427954    0.004984994011886457   0.005640606143548527
#
#                    GSM30370               GSM30371               GSM30372  \
# 0      0.010954286918053509   0.005114844376285246   0.010565692448463318
# 1     0.0076912163643633145   0.002951709595343487   0.010162010872490445
# 2      0.024298912739732507   0.012808894775365098    0.06206469670057591
# 3       0.04466408429813889    0.02160302882437001   0.045912051240648045
# 4      0.002162482857056874  0.0009105642884528248   0.003412454922224016
# ...                     ...                    ...                    ...
# 8600   0.004484035029642782  0.0008953156041964377  0.0077291565746272686
# 8601  0.0023602447087956737  0.0006295528214422641  0.0014801657785671995
# 8602   0.005081619755549155   0.001766668990275696  0.0037946068141450026
# 8603   0.006861476421198351   0.004348053396535499   0.004370525862532968
# 8604   0.021530246815389315   0.011397302289916698   0.022896818989181333
#
#                    GSM30373               GSM30374                     ID  \
# 0      0.004437375924923299   0.012218546804137576   0.007764686534553443
# 1     0.0035620826565601876  0.0027992955526507145   0.008980488435198348
# 2      0.031598538170005415   0.010730632951827739   0.024827027217516947
# 3       0.02453302652950731   0.029808714803902202   0.043874590327620436
# 4     0.0007354268182638513   0.001445882387555324   0.004334598080560092
# ...                     ...                    ...                    ...
# 8600   0.004640407868615773   0.009562158231652214  0.0060731360640909685
# 8601   0.002170185887024003   0.000361470596888831  0.0012980300485146074
# 8602    0.00475320339288937   0.004984931719885506  0.0016151957617263212
# 8603   0.004164410756181194   0.004854634179146509   0.006137743894560022
# 8604   0.011732990434939541   0.017098399862136796   0.020985798024175075
#
#         Gene Symbol
# 0     DDR1  MIR4640
# 1              RFC2
# 2             HSPA6
# 3              PAX8
# 4            GUCA1A
# ...             ...
# 8600          GAPDH
# 8601          STAT1
# 8602          STAT1
# 8603          STAT1
# 8604          STAT1
#
# [8605 rows x 16 columns]

# %%
GSE1739 = tmp
GSE1739.to_csv('GSE1739(Processed).csv')
